# %% [markdown]
# # Read the data

# %%
import pandas as pd
import os
os.chdir(r'C:\Users\Ram\Ram DS Projects\Linear Regression')
car_info= pd.read_csv('car data.csv')

# %%
car_info
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
car_info.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car_info.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car_info.columns = [cols.lower() for cols in car_info.columns] #Convert heading to lower case

# %%
car_info.head()
# Out:
#   car_name  year  selling_price  present_price  kms_driven fuel_type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   seller_type transmission  owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
print(car_info['fuel_type'].value_counts())
print('*************************')
print(car_info['seller_type'].value_counts())
print('*************************')
print(car_info['transmission'].value_counts())

# %%
car_info.fuel_type.value_counts()
# Out:
# fuel_type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.available

# %%
fuel_info= car_info['fuel_type']
seller_info = car_info.seller_type
transmission_info= car_info.transmission
selling_price= car_info.selling_price

# %%
style.use('seaborn-v0_8-dark-palette')
chart= plt.figure(figsize=(20,5))
chart.suptitle('Categorical Chart Info')
plt.subplot(1,3,1)
plt.bar(fuel_info,selling_price,color='Red')
plt.xlabel('Fuel Type')
plt.ylabel('Selling Price')

plt.subplot(1,3,2)
plt.bar(seller_info,selling_price, color='Blue')
plt.xlabel('Seller Info')
plt.ylabel('Selling Price')

plt.subplot(1,3,3)
plt.bar(transmission_info,selling_price,color='Green')
plt.xlabel('Transmission Information')
plt.ylabel('Selling Price')
# Out:
# Text(0, 0.5, 'Selling Price')

# %%
petrol_data = car_info.groupby('fuel_type').get_group('Petrol')
petrol_data.describe()

# %%
diesel_data = car_info.groupby('fuel_type').get_group('Diesel')
diesel_data.describe()

# %%
cng_data= car_info.groupby('fuel_type').get_group('CNG')
cng_data.describe()

# %%
print(car_info.fuel_type, car_info.seller_type, car_info.transmission)

# %%
car_info.replace({'fuel_type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
car_info.replace({'seller_type':{'Dealer':1,'Individual':2}},inplace=True)
car_info.replace({'transmission':{'Automatic':2,'Manual':1}},inplace=True)
print(car_info.fuel_type, car_info.seller_type, car_info.transmission)

# %%
car_info.describe()
# Out:
#               year  selling_price  present_price     kms_driven   fuel_type  \
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.212625
# std       2.891554       5.082812       8.644115   38886.883882    0.425801
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    2.000000
#
#        seller_type  transmission       owner
# count   301.000000    301.000000  301.000000
# mean      1.352159      1.132890    0.043189
# std       0.478439      0.340021    0.247915
# min       1.000000      1.000000    0.000000
# 25%       1.000000      1.000000    0.000000
# 50%       1.000000      1.000000    0.000000
# 75%       2.000000      1.000000    0.000000
# max       2.000000      2.000000    3.000000

# %%
import seaborn as sns

# %%
fig=plt.figure(figsize=(10,5))
plt.title('Correlation between Selling Price and Present Price')
sns.regplot(x= 'present_price',y='selling_price',data=car_info)
# Out:
# <Axes: title={'center': 'Correlation between Selling Price and Present Price'}, xlabel='present_price', ylabel='selling_price'>

# %%
input_data = car_info.drop(columns=['car_name','selling_price'])
output_data = car_info.selling_price

# %%
print(input_data.shape)
print(output_data.shape)
# Out:
# (301, 7)
# (301,)

# %% [markdown]
# # Standardized each colum using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
input_data =scalar.fit_transform(input_data)
print(input_data)
# Out:
# [[ 0.128897   -0.23621461 -0.25622446 ... -0.73728539 -0.39148015
#   -0.17450057]
#  [-0.21751369  0.22150462  0.1559105  ... -0.73728539 -0.39148015
#   -0.17450057]
#  [ 1.16812909  0.25742689 -0.77396901 ... -0.73728539 -0.39148015
#   -0.17450057]
#  ...
#  [-1.60315648  0.39068691  1.31334003 ... -0.73728539 -0.39148015
#   -0.17450057]
#  [ 1.16812909  0.56450434 -0.7198763  ... -0.73728539 -0.39148015
#   -0.17450057]
#  [ 0.8217184  -0.20029235 -0.81095812 ... -0.73728539 -0.39148015
#   -0.17450057]]

# %% [markdown]
# # Split data set for Test and Train

# %%
from sklearn.model_selection import train_test_split

# %%
input_data_train, input_data_test, output_data_train, output_data_test= train_test_split(input_data,output_data, test_size=0.3)

# %%
print('Input Train Data Size',input_data_train.shape)
print('Output Train Data Size',output_data_train.shape)
# Out:
# Input Train Data Size (210, 7)
# Output Train Data Size (210,)

# %%
print('Input Test Data Size',input_data_test.shape)
print('Output Test Data Size',output_data_test.shape)
# Out:
# Input Test Data Size (91, 7)
# Output Test Data Size (91,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
model = LinearRegression()
model.fit(input_data_train,output_data_train)
# Out:
# LinearRegression()

# %%
predicted_sellingprice= model.predict(input_data_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
print('Mean Absolute Error: ',(metrics.mean_absolute_error(predicted_sellingprice,output_data_test)))
print('Mean Squared Error : ', (metrics.mean_squared_error(predicted_sellingprice,output_data_test)))
print('R-Squared Error : ', (metrics.r2_score(predicted_sellingprice,output_data_test)))
# Out:
# Mean Absolute Error:  1.126540649150786
# Mean Squared Error :  2.791936579142285
# R-Squared Error :  0.846853301953481
